# %%
import os
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
from tensorflow import keras
# %env SM_FRAMEWORK=tf.keras
import segmentation_models as sm
import warnings

warnings.filterwarnings("ignore")
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %%
os.listdir('../Speech Recognition/')
# Out:
# ['.ipynb_checkpoints',
#  'test',
#  'test.7z',
#  'train',
#  'train.7z',
#  'Untitled.ipynb']

# %%
train_audio_path = '../Speech Recognition/train/audio/'
samples, sample_rate = librosa.load(train_audio_path+'yes/0a7c2a8d_nohash_0.wav', sr = 16000)
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave of ' + '../input/train/audio/yes/0a7c2a8d_nohash_0.wav')
ax1.set_xlabel('time')
ax1.set_ylabel('Amplitude')
ax1.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)

# %%
ipd.Audio(samples, rate=sample_rate)
print(sample_rate)
# Out:
# 16000

# %%
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
labels=os.listdir(train_audio_path)
labels
# Out:
# ['bed',
#  'bird',
#  'cat',
#  'dog',
#  'down',
#  'eight',
#  'five',
#  'four',
#  'go',
#  'happy',
#  'house',
#  'left',
#  'marvin',
#  'nine',
#  'no',
#  'off',
#  'on',
#  'one',
#  'right',
#  'seven',
#  'sheila',
#  'six',
#  'stop',
#  'three',
#  'tree',
#  'two',
#  'up',
#  'wow',
#  'yes',
#  'zero',
#  '_background_noise_']

# %%
#find count of each label and plot bar graph
no_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    no_of_recordings.append(len(waves))
    
#plot
plt.figure(figsize=(30,5))
index = np.arange(len(labels))
plt.bar(index, no_of_recordings)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of recordings', fontsize=12)
plt.xticks(index, labels, fontsize=15, rotation=60)
plt.title('No. of recordings for each command')
plt.show()

# %%
duration_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        sample_rate, samples = wavfile.read(train_audio_path + '/' + label + '/' + wav)
        duration_of_recordings.append(float(len(samples)/sample_rate))
    
plt.hist(np.array(duration_of_recordings), range=[0.4, 1.0])
# Out:
# (array([1.2000e+01, 9.1000e+01, 1.1100e+02, 1.5700e+02, 5.3200e+02,
#         4.9500e+02, 9.6300e+02, 8.1000e+02, 2.0400e+03, 5.9508e+04]),
#  array([0.4 , 0.46, 0.52, 0.58, 0.64, 0.7 , 0.76, 0.82, 0.88, 0.94, 1.  ]),
#  <BarContainer object of 10 artists>)

# %%
train_audio_path = '../Speech Recognition/train/audio/'

all_wave = []
all_label = []
for label in labels:
    print(label)
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
        samples = librosa.resample(samples, sample_rate, 8000)
        if(len(samples)== 8000) : 
            all_wave.append(samples)
            all_label.append(label)
# Out:
# bed
# bird
# cat
# dog
# down
# eight
# five
# four
# go
# happy
# house
# left
# marvin
# nine
# no
# off
# on
# one
# right
# seven
# sheila
# six
# stop
# three
# tree
# two
# up
# wow
# yes
# zero
# _background_noise_

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)

# %%
from keras.utils import np_utils
y=np_utils.to_categorical(y, num_classes=len(labels))
# Out:
# Using TensorFlow backend.

# %%
all_wave = np.array(all_wave).reshape(-1,8000,1)

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.2,random_state=777,shuffle=True)

# %%
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
K.clear_session()

inputs = Input(shape=(8000,1))

#First Conv1D layer
conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Second Conv1D layer
conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Third Conv1D layer
conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Fourth Conv1D layer
conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Flatten layer
conv = Flatten()(conv)

#Dense Layer 1
conv = Dense(256, activation='relu')(conv)
conv = Dropout(0.3)(conv)

#Dense Layer 2
conv = Dense(128, activation='relu')(conv)
conv = Dropout(0.3)(conv)

outputs = Dense(len(labels), activation='softmax')(conv)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8000, 1)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 7988, 8)           112
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 2662, 8)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 2662, 8)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2652, 16)          1424
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 884, 16)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 884, 16)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 876, 32)           4640
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 292, 32)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 292, 32)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 286, 64)           14400
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 95, 64)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 95, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 6080)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1556736
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 31)                3999
# =================================================================
# Total params: 1,614,207
# Trainable params: 1,614,207
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001) 
mc = ModelCheckpoint('best_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history=model.fit(x_tr, y_tr ,epochs=50, callbacks=[es,mc], batch_size=32, validation_data=(x_val,y_val))
# Out:
# Epoch 1/50
# 1457/1457 [==============================] - 125s 85ms/step - loss: 3.1393 - accuracy: 0.0977 - val_loss: 2.0331 - val_accuracy: 0.3786
# Epoch 2/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 2.0974 - accuracy: 0.3456 - val_loss: 1.6761 - val_accuracy: 0.4818
# Epoch 3/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 1.7322 - accuracy: 0.4541 - val_loss: 1.3896 - val_accuracy: 0.5745
# Epoch 4/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 1.5018 - accuracy: 0.5351 - val_loss: 1.1748 - val_accuracy: 0.6415
# Epoch 5/50
# 1457/1457 [==============================] - 127s 87ms/step - loss: 1.3344 - accuracy: 0.5838 - val_loss: 1.0270 - val_accuracy: 0.6902
# Epoch 6/50
# 1457/1457 [==============================] - 125s 86ms/step - loss: 1.2303 - accuracy: 0.6221 - val_loss: 0.9804 - val_accuracy: 0.7065
# Epoch 7/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 1.1420 - accuracy: 0.6500 - val_loss: 0.9181 - val_accuracy: 0.7212
# Epoch 8/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 1.1010 - accuracy: 0.6597 - val_loss: 0.9522 - val_accuracy: 0.7193
# Epoch 9/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 1.0440 - accuracy: 0.6791 - val_loss: 0.8507 - val_accuracy: 0.7469
# Epoch 10/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.9895 - accuracy: 0.6974 - val_loss: 0.8191 - val_accuracy: 0.7539
# Epoch 11/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.9755 - accuracy: 0.7018 - val_loss: 0.7761 - val_accuracy: 0.7731
# Epoch 12/50
# 1457/1457 [==============================] - 125s 86ms/step - loss: 0.9371 - accuracy: 0.7157 - val_loss: 0.7763 - val_accuracy: 0.7719
# Epoch 13/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.8979 - accuracy: 0.7266 - val_loss: 0.7357 - val_accuracy: 0.7857
# Epoch 14/50
# 1457/1457 [==============================] - 123s 85ms/step - loss: 0.8933 - accuracy: 0.7278 - val_loss: 0.7399 - val_accuracy: 0.7824
# Epoch 15/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.8637 - accuracy: 0.7333 - val_loss: 0.9673 - val_accuracy: 0.7035
# Epoch 16/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.8734 - accuracy: 0.7310 - val_loss: 0.7329 - val_accuracy: 0.7794
# Epoch 17/50
# 1457/1457 [==============================] - 123s 85ms/step - loss: 0.8172 - accuracy: 0.7500 - val_loss: 0.7106 - val_accuracy: 0.7859
# Epoch 18/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.8084 - accuracy: 0.7530 - val_loss: 0.7223 - val_accuracy: 0.7874
# Epoch 19/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.7941 - accuracy: 0.7594 - val_loss: 0.6715 - val_accuracy: 0.7967
# Epoch 20/50
# 1457/1457 [==============================] - 125s 86ms/step - loss: 0.7810 - accuracy: 0.7627 - val_loss: 0.6843 - val_accuracy: 0.7915
# Epoch 21/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.7684 - accuracy: 0.7628 - val_loss: 0.7076 - val_accuracy: 0.7847
# Epoch 22/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.7634 - accuracy: 0.7651 - val_loss: 0.6958 - val_accuracy: 0.7879
# Epoch 23/50
# 1457/1457 [==============================] - 123s 85ms/step - loss: 0.7490 - accuracy: 0.7731 - val_loss: 0.7580 - val_accuracy: 0.7708
# Epoch 24/50
# 1457/1457 [==============================] - 123s 84ms/step - loss: 0.7497 - accuracy: 0.7720 - val_loss: 0.6394 - val_accuracy: 0.8075
# Epoch 25/50
# 1457/1457 [==============================] - 122s 84ms/step - loss: 0.7171 - accuracy: 0.7785 - val_loss: 0.6524 - val_accuracy: 0.8018
# Epoch 26/50
# 1457/1457 [==============================] - 122s 84ms/step - loss: 0.7209 - accuracy: 0.7798 - val_loss: 0.6454 - val_accuracy: 0.8035
# Epoch 27/50
# 1457/1457 [==============================] - 123s 84ms/step - loss: 0.7129 - accuracy: 0.7837 - val_loss: 0.6685 - val_accuracy: 0.8031
# Epoch 28/50
# 1457/1457 [==============================] - 122s 84ms/step - loss: 0.6876 - accuracy: 0.7902 - val_loss: 0.6696 - val_accuracy: 0.7974
# Epoch 29/50
# 1457/1457 [==============================] - 122s 84ms/step - loss: 0.6832 - accuracy: 0.7906 - val_loss: 0.6507 - val_accuracy: 0.8021
# Epoch 30/50
# 1457/1457 [==============================] - 122s 84ms/step - loss: 0.6812 - accuracy: 0.7893 - val_loss: 0.6129 - val_accuracy: 0.8167
# Epoch 31/50
# 1457/1457 [==============================] - 122s 84ms/step - loss: 0.6883 - accuracy: 0.7893 - val_loss: 0.6343 - val_accuracy: 0.8091
# Epoch 32/50
# 1457/1457 [==============================] - 122s 84ms/step - loss: 0.6838 - accuracy: 0.7931 - val_loss: 0.6651 - val_accuracy: 0.7989
# Epoch 33/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.6785 - accuracy: 0.7937 - val_loss: 0.6261 - val_accuracy: 0.8103
# Epoch 34/50
# 1457/1457 [==============================] - 127s 87ms/step - loss: 0.6680 - accuracy: 0.7949 - val_loss: 0.6205 - val_accuracy: 0.8134
# Epoch 35/50
# 1457/1457 [==============================] - 125s 86ms/step - loss: 0.6700 - accuracy: 0.7955 - val_loss: 0.6501 - val_accuracy: 0.8032
# Epoch 36/50
# 1457/1457 [==============================] - 126s 86ms/step - loss: 0.6531 - accuracy: 0.8024 - val_loss: 0.6322 - val_accuracy: 0.8101
# Epoch 37/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.6612 - accuracy: 0.7995 - val_loss: 0.6766 - val_accuracy: 0.7959
# Epoch 38/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.6525 - accuracy: 0.8028 - val_loss: 0.6405 - val_accuracy: 0.8063
# Epoch 39/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.6454 - accuracy: 0.8014 - val_loss: 0.6126 - val_accuracy: 0.8151
# Epoch 40/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.6466 - accuracy: 0.8007 - val_loss: 0.6627 - val_accuracy: 0.7980
# Epoch 41/50
# 1457/1457 [==============================] - 125s 86ms/step - loss: 0.6340 - accuracy: 0.8064 - val_loss: 0.6593 - val_accuracy: 0.7993
# Epoch 42/50
# 1457/1457 [==============================] - 125s 86ms/step - loss: 0.6307 - accuracy: 0.8083 - val_loss: 0.6013 - val_accuracy: 0.8162
# Epoch 43/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.6343 - accuracy: 0.8073 - val_loss: 0.6063 - val_accuracy: 0.8175
# Epoch 44/50
# 1457/1457 [==============================] - 125s 86ms/step - loss: 0.6080 - accuracy: 0.8130 - val_loss: 0.5909 - val_accuracy: 0.8187
# Epoch 45/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.6142 - accuracy: 0.8107 - val_loss: 0.6087 - val_accuracy: 0.8130
# Epoch 46/50
# 1457/1457 [==============================] - 124s 85ms/step - loss: 0.5883 - accuracy: 0.8199 - val_loss: 0.6723 - val_accuracy: 0.7966
# Epoch 47/50
# 1457/1457 [==============================] - 125s 85ms/step - loss: 0.6135 - accuracy: 0.8133 - val_loss: 0.6825 - val_accuracy: 0.7964
# Epoch 48/50
# 1457/1457 [==============================] - 122s 83ms/step - loss: 0.6015 - accuracy: 0.8130 - val_loss: 0.6277 - val_accuracy: 0.8121
# Epoch 49/50
# 1457/1457 [==============================] - 123s 84ms/step - loss: 0.5979 - accuracy: 0.8181 - val_loss: 0.6195 - val_accuracy: 0.8189
# Epoch 50/50
# 1457/1457 [==============================] - 125s 86ms/step - loss: 0.5957 - accuracy: 0.8194 - val_loss: 0.7856 - val_accuracy: 0.7670

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
def predict(audio):
    prob=model.predict(audio.reshape(1,8000,1))
    index=np.argmax(prob[0])
    return classes[index]

# %%
import random
index=random.randint(0,len(x_val)-1)
samples=x_val[index].ravel()
print("Audio:",classes[np.argmax(y_val[index])])
ipd.Audio(samples, rate=8000)
# Out:
# Audio: six
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Text:",predict(samples))
# Out:
# Text: six
